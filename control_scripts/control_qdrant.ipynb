# %%
from qdrant_client import QdrantClient
from qdrant_client.http.models import PointStruct, VectorParams, Distance, QueryResponse
from ollama import Client as OllamaClient, ChatResponse
from typing import Mapping, Any, Optional, Sequence
import os

# %%
_qdrant_client: Optional["QdrantClient"] = None

def _get_qdrant_client() -> QdrantClient:
    global _qdrant_client
    if _qdrant_client is None:
        url = os.getenv("QDRANT_HOST", "http://localhost:6333")
        _qdrant_client = QdrantClient(url=url)
    return _qdrant_client

# %%
_qdrant_client = _get_qdrant_client()

# %%
_qdrant_client.get_collections()
# Out:
# CollectionsResponse(collections=[])

# %%
_qdrant_client.delete_collection(collection_name="General")
# Out:
# False

# %%
_qdrant_client.scroll(collection_name="test_collection", scroll_filter=None, limit=10)
# Out:
# ---------------------------------------------------------------------------
# UnexpectedResponse                        Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 _qdrant_client.scroll(collection_name="test_collection", scroll_filter=None, limit=10)
#
# File ~/crashout/.venv/lib/python3.13/site-packages/qdrant_client/qdrant_client.py:768, in QdrantClient.scroll(self, collection_name, scroll_filter, limit, order_by, offset, with_payload, with_vectors, consistency, shard_key_selector, timeout, **kwargs)
#     726 """Scroll over all (matching) points in the collection.
#     727
#     728 This method provides a way to iterate over all stored points with some optional filtering condition.
#    (...)    764     If next page offset is `None` - there is no more points in the collection to scroll.
#     765 """
#     766 assert len(kwargs) == 0, f"Unknown arguments: {list(kwargs.keys())}"
# --> 768 return self._client.scroll(
#     769     collection_name=collection_name,
#     770     scroll_filter=scroll_filter,
#     771     limit=limit,
#     772     order_by=order_by,
#     773     offset=offset,
#     774     with_payload=with_payload,
#     775     with_vectors=with_vectors,
#     776     consistency=consistency,
#     777     shard_key_selector=shard_key_selector,
#     778     timeout=timeout,
#     779     **kwargs,
#     780 )
#
# File ~/crashout/.venv/lib/python3.13/site-packages/qdrant_client/qdrant_remote.py:921, in QdrantRemote.scroll(self, collection_name, scroll_filter, limit, order_by, offset, with_payload, with_vectors, consistency, shard_key_selector, timeout, **kwargs)
#     917 if isinstance(with_payload, grpc.WithPayloadSelector):
#     918     with_payload = GrpcToRest.convert_with_payload_selector(with_payload)
#     920 scroll_result: Optional[models.ScrollResult] = (
# --> 921     self.openapi_client.points_api.scroll_points(
#     922         collection_name=collection_name,
#     923         consistency=consistency,
#     924         scroll_request=models.ScrollRequest(
#     925             filter=scroll_filter,
#     926             limit=limit,
#     927             order_by=order_by,
#     928             offset=offset,
#     929             with_payload=with_payload,
#     930             with_vector=with_vectors,
#     931             shard_key=shard_key_selector,
#     932         ),
#     933         timeout=timeout,
#     934     ).result
#     935 )
#     936 assert scroll_result is not None, "Scroll points API returned None result"
#     938 return scroll_result.points, scroll_result.next_page_offset
#
# File ~/crashout/.venv/lib/python3.13/site-packages/qdrant_client/http/api/points_api.py:943, in SyncPointsApi.scroll_points(self, collection_name, consistency, timeout, scroll_request)
#     933 def scroll_points(
#     934     self,
#     935     collection_name: str,
#    (...)    938     scroll_request: m.ScrollRequest = None,
#     939 ) -> m.InlineResponse20015:
#     940     """
#     941     Scroll request - paginate over all points which matches given filtering condition
#     942     """
# --> 943     return self._build_for_scroll_points(
#     944         collection_name=collection_name,
#     945         consistency=consistency,
#     946         timeout=timeout,
#     947         scroll_request=scroll_request,
#     948     )
#
# File ~/crashout/.venv/lib/python3.13/site-packages/qdrant_client/http/api/points_api.py:413, in _PointsApi._build_for_scroll_points(self, collection_name, consistency, timeout, scroll_request)
#     411 if "Content-Type" not in headers:
#     412     headers["Content-Type"] = "application/json"
# --> 413 return self.api_client.request(
#     414     type_=m.InlineResponse20015,
#     415     method="POST",
#     416     url="/collections/{collection_name}/points/scroll",
#     417     headers=headers if headers else None,
#     418     path_params=path_params,
#     419     params=query_params,
#     420     content=body,
#     421 )
#
# File ~/crashout/.venv/lib/python3.13/site-packages/qdrant_client/http/api_client.py:95, in ApiClient.request(self, type_, method, url, path_params, **kwargs)
#      93     kwargs["timeout"] = int(kwargs["params"]["timeout"])
#      94 request = self._client.build_request(method, url, **kwargs)
# ---> 95 return self.send(request, type_)
#
# File ~/crashout/.venv/lib/python3.13/site-packages/qdrant_client/http/api_client.py:130, in ApiClient.send(self, request, type_)
#     128     except ValidationError as e:
#     129         raise ResponseHandlingException(e)
# --> 130 raise UnexpectedResponse.for_response(response)
#
# UnexpectedResponse: Unexpected Response: 404 (Not Found)
# Raw response content:
# b'{"status":{"error":"Not found: Collection `test_collection` doesn\'t exist!"},"time":3.625e-6}'
