# %%
import requests

# %%
url = "http://127.0.0.1:8000/query"
data = {
    "role": "user",
    "content": "How long is a marathon?",
    "company": "Trek"
}
response = requests.post(url, json=data)
print(response.text)

# %%
url = "http://127.0.0.1:8000/ingest"
data = {
    "type":"webpage",
    "collection":"Trek", 
    "location":"https://www.parktool.com/en-us/blog/repair-help/rear-derailleur-adjustment"
}
response = requests.post(url, json=data)
print(response.text)
# Out:
# {"status":"success","message":"Successfully ingested 12 content chunks from https://www.parktool.com/en-us/blog/repair-help/rear-derailleur-adjustment","collection":"Trek","chunks_ingested":12}
