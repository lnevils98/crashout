# %%
import argparse
import json
import sys

import requests

# %%
url = "http://localhost:8000/query"
role="user"
content="What is the capital of Britain?"
timeout=60

# %%
response = requests.post(url, json = {"role": role, "content": content}, timeout=timeout)

# %%
data = response.json()

# %%
data = response.json()
print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# {
#   "message": {
#     "model": "llama3.2",
#     "created_at": "2026-03-02T19:13:36.794492342Z",
#     "done": true,
#     "done_reason": "stop",
#     "total_duration": 14281718382,
#     "load_duration": 2177203126,
#     "prompt_eval_count": 32,
#     "prompt_eval_duration": 757349251,
#     "eval_count": 63,
#     "eval_duration": 11321621551,
#     "message": {
#       "role": "assistant",
#       "content": "Britain is a term often used to refer to England, Scotland, and Wales. However, it's worth noting that these countries have their own capitals:\n\n- England: London\n- Scotland: Edinburgh\n- Wales: Cardiff\n\nSo, there isn't a single \"capital of Britain\" in the classical sense.",
#       "thinking": null,
#       "images": null,
#       "tool_name": null,
#       "tool_calls": null
#     },
#     "logprobs": null
#   }
# }

# %%
print(data["message"]["message"]["content"])
# Out:
# Britain is a bit of an outdated term, as it was commonly used to refer to the United Kingdom (UK) before the name "United Kingdom" became more widely used.
#
# However, I assume you're referring to England, Scotland, Wales, and Northern Ireland, which make up the modern-day UK. In that case, each country has its own capital:
#
# * England: London
# * Scotland: Edinburgh
# * Wales: Cardiff
# * Northern Ireland: Belfast
#
# So, there isn't a single "capital of Britain" in the classical sense. But if you're referring to the UK as a whole, the capital is indeed London.
