# %%
def this_fails():
    x = 1 / 0
    return x

# %%
try:
    this_fails()
except Exception as e:
    print(f"Caught an exception: {type(e)}")
# Out:
# Caught an exception: <class 'ZeroDivisionError'>
